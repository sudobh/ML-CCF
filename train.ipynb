# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# !unzip creditcardfraud.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# Downloading creditcardfraud.zip to /content
# 100% 66.0M/66.0M [00:03<00:00, 25.7MB/s]
# 100% 66.0M/66.0M [00:03<00:00, 17.9MB/s]
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.hist(figsize=(30,30))
plt.show()

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# Robust Scaler
from sklearn.preprocessing import RobustScaler
rob_scaler = RobustScaler()
scaled_df = df.copy()
scaled_df['Amount'] = rob_scaler.fit_transform(scaled_df['Amount'].to_numpy().reshape(-1,1))
time = scaled_df['Time']
scaled_df['Time'] = (time - time.min()) / (time.max() - time.min())
scaled_df['Time'].hist()
# Out:
# <Axes: >

# %%
scaled_df = scaled_df.sample(frac=1, random_state=1)
scaled_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  0.693938 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467  0.453377 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900  0.476770 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513   0.183556 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700  0.468326  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
# ...          ...       ...       ...       ...       ...       ...       ...
# 21440   0.183261 -2.986845 -8.663978 -1.910863  0.664058 -3.934875  0.861269
# 117583  0.432480  0.937083 -0.849673  0.524186 -0.020031 -0.606327  0.692302
# 73349   0.318852 -1.149963  1.696462  1.637114  2.658991 -0.021502  0.192287
# 267336  0.941757  1.754554 -0.699398 -0.076332  0.443915 -0.672082  0.389061
# 128037  0.454743 -0.707635  0.493302  2.648089  1.064807 -0.680271  1.183838
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 169876  0.292491 -0.523020  0.358468  ... -0.075208  0.045536  0.380739
# 127467  0.321552  0.435975 -0.704298  ... -0.128619 -0.368565  0.090660
# 137900  0.706252 -0.064966 -0.463271  ... -0.305402 -0.774704 -0.123884
# 21513   0.681867 -0.031641  0.383872  ... -0.220815 -0.419013 -0.239197
# 134700  0.373692 -0.287204 -0.084482  ... -0.160161 -0.430404 -0.076738
# ...          ...       ...       ...  ...       ...       ...       ...
# 21440   1.647511 -0.480963 -1.546866  ...  1.252092 -0.993085 -2.173147
# 117583 -0.463724  0.148857  0.785062  ... -0.143322 -0.479981 -0.237902
# 73349   0.205204  0.588754 -1.187820  ...  0.025147  0.086506 -0.262748
# 267336 -0.807534  0.202915  0.858635  ...  0.141950  0.358412  0.259748
# 128037  0.169413  0.074553  1.247988  ... -0.102350  0.323975 -0.172601
#
#              V24       V25       V26       V27       V28     Amount  Class
# 169876  0.023440 -2.220686 -0.201146  0.066501  0.221180  -0.282401      0
# 127467  0.401147 -0.261034  0.080621  0.162427  0.059456  -0.279746      0
# 137900 -0.495687 -0.018148  0.121679  0.249050  0.092516  -0.294977      0
# 21513   0.009967  0.232829  0.814177  0.098797 -0.004273  -0.084119      0
# 134700  0.258708  0.552170  0.370701 -0.034255  0.041709  -0.296793      0
# ...          ...       ...       ...       ...       ...        ...    ...
# 21440   0.145570 -0.235062 -0.227411 -0.382702  0.404045  32.002515      0
# 117583 -0.715247  0.251418  0.975406 -0.060168  0.023771   2.086495      0
# 73349   0.321538  0.341667  0.210343 -0.162047  0.031193  -0.201495      0
# 267336  0.746839 -0.560808  0.104636 -0.005853 -0.019622   1.017257      0
# 128037  0.126965 -0.001998 -0.398741 -0.385589 -0.205589   0.500245      0
#
# [284807 rows x 31 columns]

# %%
train, test, val = scaled_df[:240000], scaled_df[240000:262000], scaled_df[262000:]
train['Class'].value_counts(), test['Class'].value_counts(), val['Class'].value_counts()
# Out:
# (Class
#  0    239589
#  1       411
#  Name: count, dtype: int64,
#  Class
#  0    21955
#  1       45
#  Name: count, dtype: int64,
#  Class
#  0    22771
#  1       36
#  Name: count, dtype: int64)

# %%
train_np, test_np, val_np = train.to_numpy(), test.to_numpy(), val.to_numpy()
train_np.shape, test_np.shape, val_np.shape
# Out:
# ((240000, 31), (22000, 31), (22807, 31))

# %%
x_train, y_train = train_np[:, :-1], train_np[:, -1]
x_test, y_test = test_np[:, :-1], test_np[:, -1]
x_val, y_val = val_np[:, :-1], val_np[:, -1]
x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_val.shape, y_val.shape
# Out:
# ((240000, 30), (240000,), (22000, 30), (22000,), (22807, 30), (22807,))

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(max_iter=10000)
logistic_model.fit(x_train, y_train)
logistic_model.score(x_test, y_test)
# Out:
# 0.9991363636363636

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, logistic_model.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.83      0.56      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.92      0.78      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf.fit(x_train, y_train)
print(rf.score(x_val, y_val))
print(classification_report(y_val, rf.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
# 0.9989915376857982
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.81      0.47      0.60        36
#
#     accuracy                           1.00     22807
#    macro avg       0.90      0.74      0.80     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
gbc.fit(x_train, y_train)
print(classification_report(y_val, gbc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.67      0.67      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.83      0.83      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(class_weight='balanced')
svc.fit(x_train, y_train)
print(classification_report(y_val, svc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.98      0.99     22771
#        Fraud       0.07      0.97      0.14        36
#
#     accuracy                           0.98     22807
#    macro avg       0.54      0.98      0.56     22807
# weighted avg       1.00      0.98      0.99     22807

# %%
train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  0.693938 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467  0.453377 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900  0.476770 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513   0.183556 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700  0.468326  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 169876  0.292491 -0.523020  0.358468  ... -0.075208  0.045536  0.380739
# 127467  0.321552  0.435975 -0.704298  ... -0.128619 -0.368565  0.090660
# 137900  0.706252 -0.064966 -0.463271  ... -0.305402 -0.774704 -0.123884
# 21513   0.681867 -0.031641  0.383872  ... -0.220815 -0.419013 -0.239197
# 134700  0.373692 -0.287204 -0.084482  ... -0.160161 -0.430404 -0.076738
#
#              V24       V25       V26       V27       V28    Amount  Class
# 169876  0.023440 -2.220686 -0.201146  0.066501  0.221180 -0.282401      0
# 127467  0.401147 -0.261034  0.080621  0.162427  0.059456 -0.279746      0
# 137900 -0.495687 -0.018148  0.121679  0.249050  0.092516 -0.294977      0
# 21513   0.009967  0.232829  0.814177  0.098797 -0.004273 -0.084119      0
# 134700  0.258708  0.552170  0.370701 -0.034255  0.041709 -0.296793      0
#
# [5 rows x 31 columns]

# %%
not_frauds = scaled_df.query('Class == 0')
frauds = scaled_df.query('Class == 1')
not_frauds['Class'].value_counts(), frauds['Class'].value_counts()
# Out:
# (Class
#  0    284315
#  Name: count, dtype: int64,
#  Class
#  1    492
#  Name: count, dtype: int64)

# %%
balanced_df = pd.concat([frauds, not_frauds.sample(len(frauds), random_state=1)])
balanced_df['Class'].value_counts()
# Out:
# Class
# 1    492
# 0    492
# Name: count, dtype: int64

# %%
balanced_df = balanced_df.sample(frac=1, random_state=1)
balanced_df
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 203328  0.779949  -0.967767   2.098019  -5.222929   6.514573  -4.187674
# 256217  0.912010  -0.852415  -0.334165  -0.322246  -0.634925   2.266508
# 272521  0.955669  -7.503926  -0.360628  -3.830952   2.486103   2.497367
# 261925  0.927375  -2.783865   1.596824  -2.084844   2.512986  -1.446749
# 10568   0.101394  -5.268053   9.067613 -15.960728  10.296603  -4.708241
# ...          ...        ...        ...        ...        ...        ...
# 38172   0.227314  -1.092753   0.892560   2.301973   1.537992   0.281241
# 141592  0.488524  -1.065949  -3.902050  -1.313225   1.232990  -1.697335
# 527     0.002263  -0.829932   0.430250   1.303708   1.040559   0.822210
# 263973  0.932942  -1.475270  -0.719594   1.877788  -0.400418   1.694939
# 154371  0.586329 -25.825982  19.167239 -25.390229  11.125435 -16.682644
#
#               V6         V7         V8         V9  ...        V21       V22  \
# 203328  2.114178   0.948701  -2.448427  -3.203666  ...  -0.843268  0.796739
# 256217  1.292196   0.689168   0.109021  -0.038000  ...  -0.150160  0.246596
# 272521  1.332437  -6.783964 -15.415385   0.465512  ...  -6.389132  2.249964
# 261925 -0.828496  -0.732262  -0.203329  -0.347046  ...   0.203563  0.293268
# 10568  -3.395375 -11.161057   5.499963  -5.667376  ...   2.004110  0.191058
# ...          ...        ...        ...        ...  ...        ...       ...
# 38172  -0.083689   0.913952   0.169081  -1.434966  ...  -0.061678 -0.442512
# 141592 -0.701088   1.755443  -0.551708   0.237096  ...   0.643413 -0.824771
# 527     0.844830   0.589865   0.045791  -0.148645  ...  -0.075179  0.096038
# 263973 -0.642527  -0.269385   0.273976   0.317137  ...   0.350934  0.646347
# 154371  3.933699 -37.060311 -28.759799 -11.126624  ... -16.922016  5.703684
#
#              V23       V24       V25       V26       V27       V28     Amount  \
# 203328  1.314312 -0.352887 -1.770706  0.098133  0.956769  0.162777  12.622232
# 256217  0.690049 -0.929130 -1.185869  0.238629 -0.033681 -0.078628  -0.016768
# 272521  1.670508  0.140450  0.162147  1.207731  1.268958  0.097538  -0.135401
# 261925  0.199568  0.146868  0.163602 -0.624085 -1.333100  0.428634   1.872424
# 10568   0.622928 -1.209264 -0.374799  0.648798  1.584697  0.720056  -0.293440
# ...          ...       ...       ...       ...       ...       ...        ...
# 38172  -0.051015  0.493895  0.382985 -0.254517 -0.017237  0.066154   0.664710
# 141592 -1.153751  0.515618  0.066756  0.962949 -0.330976  0.204053  16.851813
# 527    -0.139415 -0.859739  0.121235 -0.204962 -0.292247 -0.058996   0.079648
# 263973 -0.121493  0.677786  0.177642 -0.811582 -0.097729 -0.072750  -0.293440
# 154371  3.510019  0.054330 -0.671983 -0.209431 -4.950022 -0.448413  -0.275554
#
#         Class
# 203328      1
# 256217      0
# 272521      1
# 261925      1
# 10568       1
# ...       ...
# 38172       0
# 141592      0
# 527         0
# 263973      0
# 154371      1
#
# [984 rows x 31 columns]

# %%
balanced_df_np = balanced_df.to_numpy()

x_train_b, y_train_b = balanced_df_np[:700, :-1], balanced_df_np[:700, -1].astype(int)
x_test_b, y_test_b = balanced_df_np[700:842, :-1], balanced_df_np[700:842, -1].astype(int)
x_val_b, y_val_b = balanced_df_np[842:, :-1], balanced_df_np[842:, -1].astype(int)
x_train_b.shape, y_train_b.shape, x_test_b.shape, y_test_b.shape, x_val_b.shape, y_val_b.shape
# Out:
# ((700, 30), (700,), (142, 30), (142,), (142, 30), (142,))

# %%
pd.Series(y_train_b).value_counts(), pd.Series(y_test_b).value_counts(), pd.Series(y_val_b).value_counts()
# Out:
# (0    351
#  1    349
#  Name: count, dtype: int64,
#  0    73
#  1    69
#  Name: count, dtype: int64,
#  1    74
#  0    68
#  Name: count, dtype: int64)

# %%
logistic_model_b = LogisticRegression()
logistic_model_b.fit(x_train_b, y_train_b)
print(logistic_model_b.score(x_val_b, y_val_b))
print(classification_report(y_val_b, logistic_model_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
# 0.9436619718309859
#               precision    recall  f1-score   support
#
#    Not Fraud       0.94      0.94      0.94        68
#        Fraud       0.95      0.95      0.95        74
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142

# %%
rf_b = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, rf.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
print(rf_b.score(x_test_b, y_test_b))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.65      1.00      0.79        68
#        Fraud       1.00      0.50      0.67        74
#
#     accuracy                           0.74       142
#    macro avg       0.82      0.75      0.73       142
# weighted avg       0.83      0.74      0.72       142
#
# 0.9295774647887324

# %%
gbc_b = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=2, random_state=0)
gbc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, gbc.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.72      1.00      0.84        68
#        Fraud       1.00      0.65      0.79        74
#
#     accuracy                           0.82       142
#    macro avg       0.86      0.82      0.81       142
# weighted avg       0.87      0.82      0.81       142

# %%
svc_b = LinearSVC(class_weight='balanced')
svc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, svc.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.92      0.97      0.94        68
#        Fraud       0.97      0.92      0.94        74
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.95      0.94      0.94       142

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
dt_b = DecisionTreeClassifier()
dt_b.fit(x_train_b, y_train_b)
print(classification_report(y_test_b, dt_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud']))
print(dt_b.score(x_test_b, y_test_b))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.93      0.88      0.90        73
#        Fraud       0.88      0.93      0.90        69
#
#     accuracy                           0.90       142
#    macro avg       0.90      0.90      0.90       142
# weighted avg       0.90      0.90      0.90       142
#
# 0.9014084507042254

# %%
#saving all balanced models
import pickle
pickle.dump(logistic_model_b, open('logistic_model_b.bin', 'wb'))
pickle.dump(rf_b, open('rf_b.bin', 'wb'))
pickle.dump(gbc_b, open('gbc_b.bin', 'wb'))
pickle.dump(svc_b, open('svc_b.bin', 'wb'))
pickle.dump(dt_b, open('dt_b.bin', 'wb'))

# %%
pd.DataFrame(x_val_b).to_csv('x_val_b.csv', index=False)
pd.DataFrame(y_val_b).to_csv('y_val_b.csv', index=False)
